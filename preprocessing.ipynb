# %%
from basketball_reference_web_scraper import client
import pandas as pd
import seaborn as sns
import sklearn.preprocessing as pp
from sklearn.decomposition import PCA

# Get all the games from 2018-2019 season
#seasontotals = client.players_advanced_season_totals(season_end_year=2023)

csvseasontotals = pd.read_csv('dm_project_data.csv',delimiter=';',header=0)
# Convert to dataframe

csvseasontotals = pd.DataFrame(csvseasontotals)

csvseasontotals.head()

#normalize the data
# Out:
#    Rk            Player Pos  Age   Tm   G    MP   PER    TS%   3PAr  ...  OWS  \
# 0   1  Precious Achiuwa   C   23  TOR  55  1140  15.2  0.554  0.267  ...  0.8
# 1   2      Steven Adams   C   29  MEM  42  1133  17.5  0.564  0.004  ...  1.3
# 2   3       Bam Adebayo   C   25  MIA  75  2598  20.1  0.592  0.011  ...  3.6
# 3   4      Ochai Agbaji  SG   22  UTA  59  1209   9.5  0.561  0.591  ...  0.9
# 4   5      Santi Aldama  PF   22  MEM  77  1682  13.9  0.591  0.507  ...  2.1
#
#    DWS   WS  WS/48  Unnamed: 24  OBPM  DBPM  BPM  VORP  Player-additional
# 0  1.4  2.2  0.093          NaN  -1.4  -0.8 -2.3  -0.1          achiupr01
# 1  2.1  3.4  0.144          NaN  -0.3   0.9  0.6   0.7          adamsst01
# 2  3.8  7.4  0.137          NaN   0.8   0.8  1.5   2.3          adebaba01
# 3  0.4  1.3  0.053          NaN  -1.7  -1.4 -3.0  -0.3          agbajoc01
# 4  2.4  4.6  0.130          NaN  -0.3   0.8  0.5   1.1          aldamsa01
#
# [5 rows x 30 columns]

# %%
totals = csvseasontotals.drop_duplicates(subset='Player', keep='first').reset_index(drop=True)

#drop unnamed column
totals = totals.drop(['Unnamed: 19','Unnamed: 24','Player-additional','Rk'], axis=1)
print(totals.columns)

#remove all players with less than 10 games played
totals = totals[totals.G >=20]

totals= totals[totals.MP/totals.G >= 10].reset_index(drop=True)

print(totals.shape)
totals.head(50)

#save to csv
totals.to_csv('janne.csv', sep=',')
# Out:
# Index(['Player', 'Pos', 'Age', 'Tm', 'G', 'MP', 'PER', 'TS%', '3PAr', 'FTr',
#        'ORB%', 'DRB%', 'TRB%', 'AST%', 'STL%', 'BLK%', 'TOV%', 'USG%', 'OWS',
#        'DWS', 'WS', 'WS/48', 'OBPM', 'DBPM', 'BPM', 'VORP'],
#       dtype='object')
# (398, 26)

# %%
# Out:
# /Users/erik/Documents/AIIA/.venv/lib/python3.9/site-packages/seaborn/axisgrid.py:123: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# Error in callback <function flush_figures at 0x7f8c48d40790> (for post_execute):
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~/Documents/AIIA/.venv/lib/python3.9/site-packages/PIL/ImageFile.py:515, in _save(im, fp, tile, bufsize)
#     514 try:
# --> 515     fh = fp.fileno()
#     516     fp.flush()
#
# AttributeError: '_idat' object has no attribute 'fileno'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~/Documents/AIIA/.venv/lib/python3.9/site-packages/matplotlib_inline/backend_inline.py:126, in flush_figures()
#     123 if InlineBackend.instance().close_figures:
# ...
